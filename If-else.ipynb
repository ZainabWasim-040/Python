# %%
n=8
if n%2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %%
n=input("Enter any number")
if int(n)%2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter any number 5
# Odd

# %%
n=input("Enter any number")
if int(n)%2==0:
    print("Even")
elif int(n)%2!=0:
    print("Odd")
else:
    print("Invalid input")
# Out:
# Enter any number 4
# Even
