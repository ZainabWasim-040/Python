# %%
str1="ABCD"

# %%
str1[0:3]
# Out:
# 'ABC'

# %%
str2="Zainab Wasim"

# %%
str2[0:8:2]
# Out:
# 'Zia '

# %%
str2.capitalize()
# Out:
# 'Zainab wasim'

# %%
str2.casefold()
# Out:
# 'zainab wasim'

# %%
str2.center(5)
# Out:
# 'Zainab Wasim'

# %%
str2.count(str2)
# Out:
# 1

# %%
str2.encode()
# Out:
# b'Zainab Wasim'

# %%
str2.endswith(str1)
# Out:
# False

# %%
str2.expandtabs()
# Out:
# 'Zainab Wasim'

# %%
str2.find(str1)
# Out:
# -1

# %%
str2.format()
# Out:
# 'Zainab Wasim'

# %%
str2.format_map(3)
# Out:
# 'Zainab Wasim'

# %%
str2.index(str2)
# Out:
# 0

# %%
str2.isalnum()
# Out:
# False

# %%
str2.isalpha()
# Out:
# False

# %%
str2.isascii()
# Out:
# True

# %%
str2.isdecimal()
# Out:
# False

# %%
str2.isdigit()
# Out:
# False

# %%
str2.isidentifier()
# Out:
# False

# %%
str2.islower()
# Out:
# False

# %%
str2.isnumeric()
# Out:
# False

# %%
str2.isprintable()
# Out:
# True

# %%
str2.isspace()
# Out:
# False

# %%
str2.istitle()
# Out:
# True

# %%
str2.isupper()
# Out:
# False

# %%
str2.join(str1)
# Out:
# 'AZainab WasimBZainab WasimCZainab WasimD'

# %%
str2.ljust(5)
# Out:
# 'Zainab Wasim'

# %%
str2.lower()
# Out:
# 'zainab wasim'

# %%
str2.lstrip()
# Out:
# 'Zainab Wasim'

# %%
str2.maketrans({'5':'0'})
# Out:
# {53: '0'}

# %%
str2.partition(",")
# Out:
# ('Zainab Wasim', '', '')

# %%
str3="ABCD_ZAINAB"
prefix="ABCD_" 
str3.removeprefix(prefix)
# Out:
# 'ZAINAB'

# %%
suffix="ZAINAB"
str3.removesuffix(suffix)
# Out:
# 'ABCD_'

# %%
str3.replace(str2,str1)
# Out:
# 'ABCD_ZAINAB'

# %%
str3.rfind("A")
# Out:
# 9

# %%
str3.rindex(str3)
# Out:
# 0

# %%
str3.rjust(2)
# Out:
# 'ABCD_ZAINAB'

# %%
str3.rpartition(str2)
# Out:
# ('', '', 'ABCD_ZAINAB')

# %%
str3.rsplit()
# Out:
# ['ABCD_ZAINAB']

# %%
str3.rstrip()
# Out:
# 'ABCD_ZAINAB'

# %%
str3.split()
# Out:
# ['ABCD_ZAINAB']

# %%
str3.splitlines()
# Out:
# ['ABCD_ZAINAB']

# %%
str3.startswith(str2)
# Out:
# False

# %%
str3.strip()
# Out:
# 'ABCD_ZAINAB'

# %%
str3.swapcase()
# Out:
# 'abcd_zainab'

# %%
str3.title()
# Out:
# 'Abcd_Zainab'

# %%
str3.translate(str2)
# Out:
# 'ABCD_ZAINAB'

# %%
str3.upper()
# Out:
# 'ABCD_ZAINAB'

# %%
str3.zfill(2)
# Out:
# 'ABCD_ZAINAB'

# %%
str4="Zainab"

# %%
str4[::-1]
# Out:
# 'baniaZ'
