# %%
def add(x,y):
    return x+y

# %%
add(2,5)
# Out:
# 7

# %%
def add(x,y):
    print (x+y)

# %%
add(2,5)
# Out:
# 7

# %%
def add(x,y):
    return x+y
def sub(x,y):
    return x-y
def mul(x,y):
    return x*y
def fdiv(x,y):
    return x/y
def idiv(x,y):
    return x//y

# %%
idiv(8,2)
# Out:
# 4

# %%
add(3,1)
# Out:
# 4

# %%
sub(5,3)
# Out:
# 2

# %%
mul(9,2)
# Out:
# 18

# %%
fdiv(8,2)
# Out:
# 4.0

# %%
a=int (input("Enter any number"))
b=int (input ("Enter any number"))
op=input("Enter an Operator")
if op=="+": 
    print(a+b)
elif op=="-": 
    print(a-b)
elif op=="*": 
    print(a*b)
elif op=="/": 
    print(a/b)
# Out:
# Enter any number 4
# Enter any number 3
# Enter an Operator +
# 7
