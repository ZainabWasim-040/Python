# %%
s={1,2,3,3,3,4,5,6}

# %%
s
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
type(s)
# Out:
# set

# %%
s1={1,2,3,3,3,4,5,6}
s2={2,4,6,8}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 8}

# %%
s1.intersection(s2)
# Out:
# {2, 4, 6}

# %%
s1.issubset(s2)
# Out:
# False

# %%
s1.difference(s2)
# Out:
# {1, 3, 5}

# %%
s1.issuperset(s2)
# Out:
# False
