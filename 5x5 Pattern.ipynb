# %%
a=5
for i in range(a):
    for j in range(a):
        if i==j:
            print("*",end=" ")
        else:
            print("#",end=" ")
    print()
# Out:
# * # # # #
# # * # # #
# # # * # #
# # # # * #
# # # # # *
